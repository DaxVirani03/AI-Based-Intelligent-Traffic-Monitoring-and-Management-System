# %%
# Mount Google Drive
from google.colab import drive
import os

print("Mounting Google Drive...")
drive.mount('/content/drive')

# --- USER: VERIFY THIS PATH ---
# The main project directory on your Google Drive
PROJECT_DIR = "/content/drive/MyDrive/Colab_Projects/AI-Based-Intelligent-Traffic-Monitoring-and-Management-System"
# ---

# Create the directory if it doesn't exist and navigate into it
os.makedirs(PROJECT_DIR, exist_ok=True)
os.chdir(PROJECT_DIR)

print(f"Current directory: {os.getcwd()}")
# Out:
# Mounting Google Drive...
# Mounted at /content/drive
# Current directory: /content/drive/MyDrive/Colab_Projects/AI-Based-Intelligent-Traffic-Monitoring-and-Management-System

# %%
# Clone or Pull Repository
# This cell checks if the repo exists. If not, it clones it. If it does, it pulls the latest changes.

# --- USER: EDIT THESE DETAILS ---
GIT_USERNAME = "DaxVirani03"
GIT_REPO = "AI-Based-Intelligent-Traffic-Monitoring-and-Management-System"
# ---

# Check if the .git directory exists to see if it's a repo
if not os.path.exists(os.path.join(os.getcwd(), '.git')):
    print("Repository not found. Cloning from GitHub...")
    # Clone the repository into the current directory
    # !git clone https://github.com/{DaxVirani03}/{AI-Based-Intelligent-Traffic-Monitoring-and-Management-System}.git .
else:
    print("Repository found. Pulling latest changes...")
    # !git pull

print("\n✅ Environment is synced with GitHub.")
# Out:
# Repository not found. Cloning from GitHub...
# fatal: destination path '.' already exists and is not an empty directory.
#
# ✅ Environment is synced with GitHub.

# %%
# Install Dependencies
print("Installing required libraries from requirements.txt...")
# !pip install -r requirements.txt
print("\n✅ Dependencies installed.")
# Out:
# Installing required libraries from requirements.txt...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 27.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 60.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 61.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.4 MB/s eta 0:00:00
# ...

# %%
# Configure Git (Optional but Recommended)
# This helps identify who made the commits.

# --- USER: EDIT THESE DETAILS ---
GIT_USER_NAME = "DaxVirani03"
GIT_USER_EMAIL = "daxvirani03@gmail.com"
# ---

# !git config --global user.name "{GIT_USER_NAME}"
# !git config --global user.email "{GIT_USER_EMAIL}"

print("\n✅ Git user configured for this session.")
# Out:
# ✅ Git user configured for this session.
